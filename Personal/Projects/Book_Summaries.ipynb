# %%
import csv
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
import json
from IPython.display import clear_output

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.metrics import f1_score, accuracy_score

# %%
titles = []
authors = []
genres = []
summaries = []

with open('./data/book_summaries/booksummaries.txt', 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    for row in reader:
        titles.append(row[2])
        authors.append(row[3])
        genres.append(row[5])
        summaries.append(row[6])

dataset = pd.DataFrame({
    'title': titles, 
    'author': authors, 
    'summary': summaries,
    'genre': genres}
)

dataset.drop(dataset[dataset['genre']==''].index, inplace=True)

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

def process_text(text):
    eng_stopwords = set(stopwords.words('english'))
    text = re.sub('\'', '', text)
    text = re.sub('[^a-zA-Z]', ' ',text)
    text = ' '.join([stemmer.stem(lemmatizer.lemmatize(word)) for word in text.split()])
    text = ' '.join([word for word in text.split() if word not in eng_stopwords])
    text = ' '.join(text.split())
    text = text.lower()
    return text

def process_genre(raw_genre):
    return list(json.loads(raw_genre).values())
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yourlogarithm/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/yourlogarithm/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
dataset['summary'] = dataset['summary'].apply(process_text)
dataset['genre'] = dataset['genre'].apply(process_genre)

# %%
dataset['genre'][0]
# Out:
# ['Roman à clef',
#  'Satire',
#  "Children's literature",
#  'Speculative fiction',
#  'Fiction']

# %%
multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(dataset['genre'])

y = multilabel_binarizer.transform(dataset['genre'])
print(y.shape)
# Out:
# (12841, 227)

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset['summary'], y, test_size=0.2)

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=10_000)
x_train_vectorized = tfidf_vectorizer.fit_transform(x_train)
x_test_vectorized = tfidf_vectorizer.transform(x_test)

# %%
print(x_train_vectorized.shape)
print(y_train.shape)
# Out:
# (10272, 10000)
# (10272, 227)

# %%
classifier = OneVsRestClassifier(LogisticRegression())

# %%
classifier.fit(x_train_vectorized, y_train)
clear_output()

# %%
print(f'Train score: {classifier.score(x_train_vectorized, y_train): .2%}')
print(f'Test score: {classifier.score(x_test_vectorized, y_test): .2%}')
# Out:
# Train score:  17.42%
# Test score:  7.40%

# %%
predictions = classifier.predict(x_test_vectorized)
f1_score(y_test, predictions, average='micro'), accuracy_score(y_test, predictions)
# Out:
# (0.3704714640198511, 0.07395873880887505)

# %%
pred_proba = classifier.predict_proba(x_test_vectorized)
t = 0.3
pred_proba = (pred_proba >= t).astype(int)

f1_score(y_test, pred_proba, average="micro"), accuracy_score(y_test, pred_proba)
# Out:
# (0.5357556327366639, 0.11755546905410666)

# %%
def predict(m):
    m = process_text(m)
    m_vec = tfidf_vectorizer.transform([m])
    m_pred = classifier.predict(m_vec)
    return multilabel_binarizer.inverse_transform(m_pred)

# %%
for i in range(100):
    k = x_test.sample(1).index[0]
    print("Book: ", dataset['title'][k])
    print("Predicted genre: ", predict(x_test[k]))
    print("Actual genre: ", dataset['genre'][k], "\n")
# Out:
# Book:  A Summons to Memphis
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  The Humbling
# Predicted genre:  [('Fiction', 'Novel')]
# Actual genre:  ['Novel']
#
# Book:  The Last Letter Home
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Fiction', 'Historical novel']
#
# Book:  United!
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  The Candle in the Wind
# Predicted genre:  [('Fantasy', 'Speculative fiction')]
# Actual genre:  ['Speculative fiction', 'Fantasy']
#
# Book:  The Bladerunner
# Predicted genre:  [()]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Dystopia']
#
# Book:  The Kid Who Only Hit Homers
# Predicted genre:  [()]
# Actual genre:  ["Children's literature"]
#
# Book:  Stormed Fortress
# Predicted genre:  [('Fantasy', 'Speculative fiction')]
# Actual genre:  ['Fantasy', 'High fantasy']
#
# Book:  Dark Gold
# Predicted genre:  [()]
# Actual genre:  ['Speculative fiction', 'Fantasy', 'Fiction', 'Romance novel']
#
# Book:  After 12,000 Years
# Predicted genre:  [('Science Fiction',)]
# Actual genre:  ['Science Fiction']
#
# Book:  Dorian, an Imitation
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Novel']
#
# Book:  3 NBs of Julian Drew
# Predicted genre:  [()]
# Actual genre:  ['Young adult literature', 'Novel']
#
# Book:  Pichilemu Blues
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  The Gun Seller
# Predicted genre:  [()]
# Actual genre:  ['Thriller', 'Comedy']
#
# Book:  Tom Swift in the Land of Wonders
# Predicted genre:  [()]
# Actual genre:  ['Young adult literature', 'Adventure novel']
#
# Book:  Natani
# Predicted genre:  [('Fiction', 'Novel')]
# Actual genre:  ['Romance novel']
#
# Book:  Keeping the Moon
# Predicted genre:  [('Fiction',)]
# Actual genre:  ["Children's literature", 'Young adult literature', 'Fiction']
#
# Book:  The Shadow in the Glass
# Predicted genre:  [()]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fiction']
#
# Book:  Flashman on the March
# Predicted genre:  [()]
# Actual genre:  ['Historical fiction', 'Fiction', 'Historical novel']
#
# Book:  Misquoting Jesus
# Predicted genre:  [()]
# Actual genre:  ['Religion']
#
# Book:  Dead Mountaineer's Hotel
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Science Fiction']
#
# Book:  Gilgamesh the King
# Predicted genre:  [()]
# Actual genre:  ['Speculative fiction', 'Fantasy']
#
# Book:  The Tale of Mrs. Tittlemouse
# Predicted genre:  [("Children's literature", 'Fiction')]
# Actual genre:  ["Children's literature", 'Fiction']
#
# Book:  Bones of the Moon
# Predicted genre:  [()]
# Actual genre:  ['Fantasy', 'Speculative fiction', 'Horror', 'Fiction']
#
# Book:  The Big Nowhere
# Predicted genre:  [()]
# Actual genre:  ['Crime Fiction', 'Mystery', 'Novel', 'Fiction', 'Suspense']
#
# Book:  The Vicomte de Bragelonne
# Predicted genre:  [()]
# Actual genre:  ['History']
#
# Book:  When The Road Ends
# Predicted genre:  [()]
# Actual genre:  ['Young adult literature', 'Fiction']
#
# Book:  The Reign of the Brown Magician
# Predicted genre:  [('Fantasy', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction']
#
# Book:  The Naked God
# Predicted genre:  [('Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel']
#
# Book:  King of Shadows
# Predicted genre:  [()]
# Actual genre:  ['Speculative fiction', "Children's literature", 'Fiction']
#
# Book:  Foreigner
# Predicted genre:  [('Fiction', 'Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', 'Fiction']
#
# Book:  The Bone People
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Mystery', 'Fiction']
#
# Book:  Xiagu Danxin
# Predicted genre:  [()]
# Actual genre:  ['Wuxia']
#
# Book:  Skydive!
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Young adult literature']
#
# Book:  The Talisman Ring
# Predicted genre:  [()]
# Actual genre:  ['Historical fiction', 'Historical whodunnit', 'Romance novel', 'Mystery', 'Suspense', 'Regency romance', 'Fiction']
#
# Book:  Grave Matter
# Predicted genre:  [('Speculative fiction',)]
# Actual genre:  ['Science Fiction', 'Speculative fiction']
#
# Book:  Socks
# Predicted genre:  [()]
# Actual genre:  ["Children's literature", 'Fiction', 'Novel']
#
# Book:  A March into Darkness
# Predicted genre:  [()]
# Actual genre:  ['Fantasy']
#
# Book:  Sufferings in Africa: The Incredible True Story of a Shipwreck, Enslavement, and Survival on the Sahara
# Predicted genre:  [()]
# Actual genre:  ['Non-fiction']
#
# Book:  Dragons' Wrath
# Predicted genre:  [('Speculative fiction',)]
# Actual genre:  ['Speculative fiction']
#
# Book:  Dragonquest
# Predicted genre:  [('Fantasy', 'Fiction', 'Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', "Children's literature", 'Fantasy', 'Speculative fiction', 'Fiction']
#
# Book:  Transformers: Exiles
# Predicted genre:  [('Science Fiction',)]
# Actual genre:  ['Fantasy']
#
# Book:  Child of the Northern Spring
# Predicted genre:  [()]
# Actual genre:  ['Historical novel']
#
# Book:  Fallen
# Predicted genre:  [()]
# Actual genre:  ['Mystery', 'Fiction']
#
# Book:  A Summons to Memphis
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  Conan the Wanderer
# Predicted genre:  [('Fantasy',)]
# Actual genre:  ['Fantasy', 'Speculative fiction', 'Short story', 'Sword and sorcery']
#
# Book:  Way Station
# Predicted genre:  [('Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fiction']
#
# Book:  A Girl from Lübeck
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  Shopaholic & Baby
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Chick lit', 'Comedy']
#
# Book:  Look Me in the Eye
# Predicted genre:  [()]
# Actual genre:  ['Autobiography', 'Biography', 'Memoir']
#
# Book:  Babylon 5: Legions of Fire - Armies of Light and Dark
# Predicted genre:  [()]
# Actual genre:  ['Science Fiction', 'Speculative fiction']
#
# Book:  The Elfstones of Shannara
# Predicted genre:  [('Fantasy', 'Speculative fiction')]
# Actual genre:  ['High fantasy', "Children's literature", 'Fantasy', 'Speculative fiction', 'Fiction']
#
# Book:  A House Divided
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  Empress of Mijak
# Predicted genre:  [()]
# Actual genre:  ['Fantasy']
#
# Book:  Straight and Crooked Thinking
# Predicted genre:  [()]
# Actual genre:  ['Education', 'Psychology']
#
# Book:  Dragon Haven
# Predicted genre:  [('Fantasy',)]
# Actual genre:  ['Fantasy']
#
# Book:  The Descent
# Predicted genre:  [('Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Fantasy', 'Science Fiction', 'Speculative fiction', 'Horror', 'Fiction']
#
# Book:  Complicity
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  The Devil Wears Prada
# Predicted genre:  [()]
# Actual genre:  ['Chick lit', 'Fiction', 'Roman à clef']
#
# Book:  Eye of the Needle
# Predicted genre:  [()]
# Actual genre:  ['Fiction', 'Suspense']
#
# Book:  The prophecy of the stones
# Predicted genre:  [('Fantasy', 'Speculative fiction')]
# Actual genre:  ['Fantastique', 'Speculative fiction', 'Fantasy']
#
# Book:  Faerie Tale
# Predicted genre:  [()]
# Actual genre:  ['Speculative fiction', 'Fantasy']
#
# Book:  The Treasure of El Patron
# Predicted genre:  [()]
# Actual genre:  ['Young adult literature']
#
# Book:  Twenty Thousand Leagues Under the Sea
# Predicted genre:  [('Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', "Children's literature", 'Novel', 'Adventure novel', 'Fiction', 'Scientific romance']
#
# Book:  The Blunderer
# Predicted genre:  [()]
# Actual genre:  ['Thriller', 'Mystery', 'Fiction', 'Suspense']
#
# Book:  Starring Sally J. Freedman as Herself
# Predicted genre:  [("Children's literature", 'Fiction')]
# Actual genre:  ["Children's literature", 'Young adult literature', 'Fiction']
#
# Book:  Lady Friday
# Predicted genre:  [('Speculative fiction',)]
# Actual genre:  ['Fantasy', 'Speculative fiction', 'Young adult literature', "Children's literature"]
#
# Book:  Destiny's Road
# Predicted genre:  [()]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fantasy']
#
# Book:  The Bellmaker
# Predicted genre:  [("Children's literature", 'Fantasy', 'Fiction', 'Speculative fiction')]
# Actual genre:  ["Children's literature", 'Fantasy', 'Speculative fiction', 'Fiction']
#
# Book:  On Stranger Tides
# Predicted genre:  [('Speculative fiction',)]
# Actual genre:  ['Historical fantasy', 'Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction']
#
# Book:  The Princess Bride
# Predicted genre:  [('Fiction', 'Speculative fiction')]
# Actual genre:  ["Children's literature", 'Fantasy', 'Speculative fiction', 'Romance novel', 'Fiction']
#
# Book:  The Pandora Principle
# Predicted genre:  [('Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction']
#
# Book:  The Nest of the Sparrowhawk
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Historical novel']
#
# Book:  Careful, He Might Hear You
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  Unforgettable
# Predicted genre:  [()]
# Actual genre:  ['Young adult literature']
#
# Book:  Air
# Predicted genre:  [()]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fantasy']
#
# Book:  If Israel Lost the War
# Predicted genre:  [()]
# Actual genre:  ['Alternate history']
#
# Book:  Setting Free the Bears
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  Axis
# Predicted genre:  [('Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', 'Novel']
#
# Book:  Smith's Gazelle
# Predicted genre:  [()]
# Actual genre:  ['Adventure novel']
#
# Book:  Wings of Wrath
# Predicted genre:  [('Fantasy', 'Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Fantasy']
#
# Book:  Divine Right's Trip
# Predicted genre:  [()]
# Actual genre:  ['Fantasy']
#
# Book:  The Mezzanine: A Novel
# Predicted genre:  [()]
# Actual genre:  ['Novel']
#
# Book:  The Ash Garden
# Predicted genre:  [()]
# Actual genre:  ['Fiction']
#
# Book:  Allegiance
# Predicted genre:  [()]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fiction']
#
# Book:  Chasing the Bear
# Predicted genre:  [()]
# Actual genre:  ['Detective fiction']
#
# Book:  The Soft Machine
# Predicted genre:  [('Speculative fiction',)]
# Actual genre:  ['Speculative fiction', 'Novel']
#
# Book:  The Outward Urge
# Predicted genre:  [('Science Fiction', 'Speculative fiction')]
# Actual genre:  ['Science Fiction', 'Speculative fiction']
#
# Book:  The Face of Fear
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Speculative fiction', 'Horror', 'Suspense']
#
# Book:  The Man From Santa Clara
# Predicted genre:  [()]
# Actual genre:  ['Western fiction']
#
# Book:  Palace Walk
# Predicted genre:  [('Fiction', 'Novel')]
# Actual genre:  ['Novel']
#
# Book:  The Lake
# Predicted genre:  [('Fiction', 'Novel')]
# Actual genre:  ['Novel']
#
# Book:  Peter Pan in Kensington Gardens
# Predicted genre:  [("Children's literature", 'Fiction')]
# Actual genre:  ['Science Fiction', "Children's literature", 'Fantasy', 'Speculative fiction', 'Fiction']
#
# Book:  Trapped At Sea
# Predicted genre:  [()]
# Actual genre:  ['Mystery', 'Detective fiction', "Children's literature", 'Fiction']
#
# Book:  Coots in the North
# Predicted genre:  [("Children's literature",)]
# Actual genre:  ["Children's literature", 'Adventure novel']
#
# Book:  Warrior's Refuge
# Predicted genre:  [("Children's literature",)]
# Actual genre:  ["Children's literature", 'Fantasy']
#
# Book:  The Gospel According to Larry
# Predicted genre:  [()]
# Actual genre:  ['Politics', 'Novel', 'Speculative fiction', 'Romance novel', 'Fiction', 'Comedy']
#
# Book:  Eulalia
# Predicted genre:  [("Children's literature", 'Fantasy', 'Fiction', 'Speculative fiction')]
# Actual genre:  ['Speculative fiction', 'Fantasy']
#
# Book:  3rd Degree
# Predicted genre:  [('Fiction',)]
# Actual genre:  ['Crime Fiction', 'Mystery', 'Fiction', 'Suspense']
#
# Book:  Under the Skin
# Predicted genre:  [('Science Fiction',)]
# Actual genre:  ['Science Fiction', 'Speculative fiction', 'Fiction']
